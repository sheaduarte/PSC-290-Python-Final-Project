# %% [markdown]
# ## Auditory N400: Data Cleaning
# Elizabeth Pierotti // last updated 5.26.2020
#
# **Goal of this notebook:** import two dfs: one contains all data, and one contains the difference wave data. For each df, remove irrelevant columns and rename these columns. Next, remove outliers with respect to MNA values for both dfs. Save dfs to processed data directory so they can be used for plotting and stats.
#
#
# ### Set up:

# %%
# import packages:
import pandas as pd
import numpy as np
from glob import glob
import os

# %%
# change current directory to path that contains Analysis Helper
os.chdir(os.path.dirname(os.path.abspath('/Users/elizabethpierotti/Documents/GitHub/PSC-290-Python-Final-Project/AnalysisHelper.py')))

# import .py file with functions:
import AnalysisHelper as ah

# %%
# set up current and output directories:

input_directory = '/Users/elizabethpierotti/Documents/GitHub/PSC-290-Python-Final-Project/pierotti/data/interim/'
output_directory = '/Users/elizabethpierotti/Documents/GitHub/PSC-290-Python-Final-Project/pierotti/data/processed/'

# %%
# read in interim and behavioral data:

alldatafname = 'Merged_Data.csv'
diffdatafname = 'MNA_diff_data copy.csv'

alldf = pd.read_csv(input_directory + alldatafname)
diffdf = pd.read_csv(input_directory + diffdatafname)

# preview all data df:
alldf
# Out:
#    Subject Group  Condition Electrode     MNA Gender Bilingual  Age_mos  \
# 0      942    CI    Related        Fz -15.608      F        no       56
# 1      959    CI    Related        Fz  -8.930      F        no       57
# 2      925    CI    Related        Fz -12.589      M       yes       58
# 3      956    CI    Related        Fz  -7.367      F       yes       58
# 4      955    CI    Related        Fz  -2.817      M       yes       61
# ..     ...   ...        ...       ...     ...    ...       ...      ...
# 81     809    HG  Unrelated        Fz -13.547      F        no       99
# 82   N4C09    HG  Unrelated        Fz -11.510      M       yes       99
# 83     850    HG  Unrelated        Fz -22.286      F        no      124
# 84     801    HG  Unrelated        Fz -24.316      M       yes      127
# 85     803    HG  Unrelated        Fz -15.158      M        no      128
#
#     TiS_mos  Age_act_mos  ROWPVT  EOWPVT  TROG   Region
# 0        43         13.0    77.0    88.0   NaN  Frontal
# 1        17         40.0    79.0    91.0   NaN  Frontal
# 2        52          6.0    83.0    93.0   NaN  Frontal
# 3         5         53.0    66.0    61.0   NaN  Frontal
# 4        49         12.0    39.0    32.0   NaN  Frontal
# ..      ...          ...     ...     ...   ...      ...
# 81       99          NaN    97.0    87.0  75.0  Frontal
# 82       99          NaN     NaN     NaN   NaN  Frontal
# 83      124          NaN    61.0    37.0  40.0  Frontal
# 84      127          NaN     NaN     NaN  50.0  Frontal
# 85      128          NaN    99.0    99.0  95.0  Frontal
#
# [86 rows x 14 columns]

# %%
# preview difference df:
diffdf
# Out:
#    Subject Group  Condition Electrode     MNA Gender Bilingual  Age_mos  \
# 0      942    CI  Unrelated        Fz -19.676      F        no       56
# 1      959    CI  Unrelated        Fz -15.051      F        no       57
# 2      925    CI  Unrelated        Fz -15.040      M       yes       58
# 3      956    CI  Unrelated        Fz -20.795      F       yes       58
# 4      955    CI  Unrelated        Fz  -2.808      M       yes       61
# 5      904    CI  Unrelated        Fz -20.640      M       yes       67
# 6      911    CI  Unrelated        Fz -17.359      F        no       67
# 7      919    CI  Unrelated        Fz -15.457      F        no       74
# 8      954    CI  Unrelated        Fz -56.069      M       yes       74
# 9      945    CI  Unrelated        Fz -16.922      M        no       77
# 10     961    CI  Unrelated        Fz -19.604      M        no       77
# 16       74         13.0    61.0    61.0   NaN  Frontal   -11.566
# 17       80          9.0     NaN     NaN   NaN  Frontal    -7.093
# 18       49         40.0     2.0     1.0   NaN  Frontal     0.316
# 19       86         14.0     6.0    13.0   NaN  Frontal    -0.756
# 20       87         15.0    21.0    37.0   NaN  Frontal   -10.610
# 21       35         71.0    63.0    21.0   NaN  Frontal     2.484
# 22       27         79.0    81.0    77.0   NaN  Frontal   -13.056
# 23       80         42.0     NaN     NaN   NaN  Frontal    -3.303
# 24       55         67.0     NaN     NaN  10.0  Frontal   -13.217
# 25       33          NaN    37.0    70.0   NaN  Frontal     5.293
# 26       43          NaN    86.0    91.0  80.0  Frontal     0.175
# 27       51          NaN    93.0    61.0   NaN  Frontal   -12.207
# 28       52          NaN    94.0    66.0   NaN  Frontal    -0.460
# 29       56          NaN    83.0    47.0   NaN  Frontal    -9.465
# 30       59          NaN    96.0    79.0  90.0  Frontal     8.188
# 31       68          NaN     NaN     NaN   NaN  Frontal    -7.165
# 32       61          NaN     NaN     NaN  40.0  Frontal   -13.452
# 33       67          NaN    61.0    42.0   NaN  Frontal    -3.214
# 34       74          NaN    84.0    47.0  40.0  Frontal    -1.423
# 35       78          NaN    94.0    66.0   NaN  Frontal    -5.470
# 36       82          NaN     NaN     NaN   NaN  Frontal    -3.473
# 37       85          NaN    79.0     NaN   NaN  Frontal     2.461
# 38       99          NaN    97.0    87.0  75.0  Frontal     4.761
# 39       99          NaN     NaN     NaN   NaN  Frontal     3.015
# 40      124          NaN    61.0    37.0  40.0  Frontal    -7.178
# 41      127          NaN     NaN     NaN  50.0  Frontal   -11.011
# 42      128          NaN    99.0    99.0  95.0  Frontal    -3.417

# %%
# remove irrelevat columns from each df:

alldf_rel_cols = '/Users/elizabethpierotti/Documents/GitHub/PSC-290-Python-Final-Project/pierotti/data/relevant_cols.txt'
diffdf_rel_cols = '/Users/elizabethpierotti/Documents/GitHub/PSC-290-Python-Final-Project/pierotti/data/diff relevant cols.txt'

alldf = ah.filter_columns(alldf_rel_cols, alldf)
diffdf = ah.filter_columns(diffdf_rel_cols, diffdf)

print(alldf.shape, diffdf.shape)
# Out:
# (86, 8) (43, 9)

# %%
# rename columns in each df:
alldf_names = '/Users/elizabethpierotti/Documents/GitHub/PSC-290-Python-Final-Project/pierotti/data/col_names.txt'
diffdf_names = '/Users/elizabethpierotti/Documents/GitHub/PSC-290-Python-Final-Project/pierotti/data/diff_col_names.txt'

alldf = ah.rename_columns(alldf_names, alldf)
diffdf = ah.rename_columns(diffdf_names, diffdf)

print(alldf.columns, diffdf.columns)
# Out:
# Index(['ID', 'Group', 'Condition', 'Mean Amplitude', 'Age (months)',
#        'Time in Sound (months)', 'Age of Activation (months)', 'Region'],
#       dtype='object') Index(['ID', 'Group', 'Mean Amplitude', 'Bilingual', 'Age (months)',
#        'Time in Sound (months)', 'Age of Activation (months)', 'Region',
#        'Mean Amplitude Difference'],
#       dtype='object')

# %%
# remove outliers based on MNA in each df:
alldf = ah.remove_outliers(alldf, 'Mean Amplitude')
diffdf = ah.remove_outliers(diffdf, 'Mean Amplitude')

print(alldf.shape, diffdf.shape)
# Out:
# (81, 8) (40, 9)

# %%
# save dfs to /processed data:

alldf.to_csv(output_directory + 'all_data_processed.csv', index=False)
diffdf.to_csv(output_directory + 'diff_data_processed.csv', index = False)
