# %% [markdown]
# ## Auditory N400: Data Visualization
# Elizabeth Pierotti // last updated 5.27.2020
#
# **Goal of this notebook:** import two dfs: one contains all data, and one contains the difference wave data. For the df with all data, I will create some plots that let me look at distributions between groups (bar plots, histograms, violin plots, boxplots). For the difference wave df, I want to look at a regression plot of some variables, and make a scatterplot matrix as well.
#
#
# ### Set up:

# %%
# import packages:
import pandas as pd
import os
import altair as alt
from altair_saver import save
import seaborn as sns

# %%
# change current directory to path that contains Analysis Helper
os.chdir(os.path.dirname(os.path.abspath('/Users/elizabethpierotti/Documents/GitHub/PSC-290-Python-Final-Project/AnalysisHelper.py')))

# import .py file with functions:
import AnalysisHelper as ah

# %%
# set up data and output directories:

data_directory = '/Users/elizabethpierotti/Documents/GitHub/PSC-290-Python-Final-Project/pierotti/data/processed/'
output_directory = '/Users/elizabethpierotti/Documents/GitHub/PSC-290-Python-Final-Project/pierotti/reports/figures/'

# %%
# read in interim and behavioral data:

all_fname = 'all_data_processed.csv'
diff_fname = 'diff_data_processed.csv'

alldf = pd.read_csv(data_directory + all_fname)
diffdf = pd.read_csv(data_directory + diff_fname)

# preview all data df:
alldf
# Out:
#     Unnamed: 0     ID Group  Condition  Mean Amplitude  Age (months)  \
# 0            0    942    CI    Related         -15.608            56
# 1            1    959    CI    Related          -8.930            57
# 2            2    925    CI    Related         -12.589            58
# 3            3    956    CI    Related          -7.367            58
# 4            4    955    CI    Related          -2.817            61
# ..         ...    ...   ...        ...             ...           ...
# 76          81    809    HG  Unrelated         -13.547            99
# 77          82  N4C09    HG  Unrelated         -11.510            99
# 78          83    850    HG  Unrelated         -22.286           124
# 79          84    801    HG  Unrelated         -24.316           127
# 80          85    803    HG  Unrelated         -15.158           128
#
#     Time in Sound (months)  Age of Activation (months)   Region
# 0                       43                        13.0  Frontal
# 1                       17                        40.0  Frontal
# 2                       52                         6.0  Frontal
# 3                        5                        53.0  Frontal
# 4                       49                        12.0  Frontal
# ..                     ...                         ...      ...
# 76                      99                         NaN  Frontal
# 77                      99                         NaN  Frontal
# 78                     124                         NaN  Frontal
# 79                     127                         NaN  Frontal
# 80                     128                         NaN  Frontal
#
# [81 rows x 9 columns]

# %%
# preview diff df:
diffdf
# Out:
#     Unnamed: 0     ID Group  Mean Amplitude Bilingual  Age (months)  \
# 0            0    942    CI         -19.676        no            56
# 1            1    959    CI         -15.051        no            57
# 2            2    925    CI         -15.040       yes            58
# 3            3    956    CI         -20.795       yes            58
# 4            4    955    CI          -2.808       yes            61
# 5            5    904    CI         -20.640       yes            67
# 6            6    911    CI         -17.359        no            67
# 7            7    919    CI         -15.457        no            74
# 8            9    945    CI         -16.922        no            77
# 9           10    961    CI         -19.604        no            77
# 10          11    903    CI         -24.758        no            82
# 11          12    921    CI         -33.187       yes            82
# 12          13    936    CI          -6.697       yes            86
# 13          14    901    CI          -3.359       yes            86
# 14          15    923    CI         -22.510       yes            87
# 15          16    924    CI         -18.952       yes            87
# 16          17    934    CI         -14.017       yes            89
# 17          18    951    CI         -19.705        no            89
# 18          19    913    CI         -15.578       yes           100
# 19          21    941    CI         -19.012        no           106
# 20          22    947    CI         -19.223        no           106
# 21          23    935    CI         -16.625       yes           122
# 22          24    937    CI         -27.731        no           122
# 23          25    857    HG          -8.053        no            33
# 24          26    847    HG          -2.966        no            43
# 25          27    858    HG         -18.587        no            51
# 26          28    859    HG          -7.700        no            52
# 27          29    841    HG         -28.017        no            56
# 28          30    836    HG          -8.181        no            59
# 29          31    846    HG         -27.161       yes            68
# 30          32  N4C01    HG         -17.461        no            61
# 31          33    842    HG         -18.281       yes            67
# 32          34    848    HG         -15.101        no            74
# 33          36  N4C10    HG          -9.489       yes            82
# 34          37  N4C13    HG         -25.547       yes            85
# 35          38    809    HG         -13.547        no            99
# 36          39  N4C09    HG         -11.510       yes            99
# 37          40    850    HG         -22.286        no           124
# 38          41    801    HG         -24.316       yes           127
# 39          42    803    HG         -15.158        no           128
#
#     Time in Sound (months)  Age of Activation (months)   Region  \
# 0                       43                        13.0  Frontal
# 1                       17                        40.0  Frontal
# 2                       52                         6.0  Frontal
# 3                        5                        53.0  Frontal
# 4                       49                        12.0  Frontal
# 5                       54                        13.0  Frontal
# 6                       54                        13.0  Frontal
# 7                       67                         7.0  Frontal
# 8                       56                        21.0  Frontal
# 9                       63                        14.0  Frontal
# 10                      72                        10.0  Frontal
# 11                      46                        36.0  Frontal
# 12                      71                        15.0  Frontal
# 13                      68                        18.0  Frontal
# 14                      56                        31.0  Frontal
# 15                      74                        13.0  Frontal
# 16                      80                         9.0  Frontal
# 17                      49                        40.0  Frontal
# 18                      86                        14.0  Frontal
# 19                      35                        71.0  Frontal
# 20                      27                        79.0  Frontal
# 21                      80                        42.0  Frontal
# 22                      55                        67.0  Frontal
# 23                      33                         NaN  Frontal
# 24                      43                         NaN  Frontal
# 25                      51                         NaN  Frontal
# 26                      52                         NaN  Frontal
# 27                      56                         NaN  Frontal
# 28                      59                         NaN  Frontal
# 29                      68                         NaN  Frontal
# 30                      61                         NaN  Frontal
# 31                      67                         NaN  Frontal
# 32                      74                         NaN  Frontal
# 33                      82                         NaN  Frontal
# 34                      85                         NaN  Frontal
# 35                      99                         NaN  Frontal
# 36                      99                         NaN  Frontal
# 37                     124                         NaN  Frontal
# 38                     127                         NaN  Frontal
# 39                     128                         NaN  Frontal
#
#     Mean Amplitude Difference
# 0                      -4.068
# 1                      -6.121
# 2                      -2.451
# 3                     -13.428
# 4                       0.009
# 5                      -0.795
# 6                      -1.122
# 7                      -1.454
# 8                      -8.067
# 9                     -15.951
# 10                     -4.641
# 11                      4.483
# 12                     -9.298
# 13                     24.661
# 14                    -14.398
# 15                    -11.566
# 16                     -7.093
# 17                      0.316
# 18                     -0.756
# 19                      2.484
# 20                    -13.056
# 21                     -3.303
# 22                    -13.217
# 23                      5.293
# 24                      0.175
# 25                    -12.207
# 26                     -0.460
# 27                     -9.465
# 28                      8.188
# 29                     -7.165
# 30                    -13.452
# 31                     -3.214
# 32                     -1.423
# 33                     -3.473
# 34                      2.461
# 35                      4.761
# 36                      3.015
# 37                     -7.178
# 38                    -11.011
# 39                     -3.417

# %% [markdown]
# ### All data visualization:

# %%
# histogram of age of activation:
ah.histogram(alldf, 'Age of Activation (months)', output_directory)
# Out:
# alt.Chart(...)

# %%
# histogram of time in sound:
ah.histogram(alldf, 'Time in Sound (months)', output_directory)
# Out:
# alt.Chart(...)

# %%
# bar plot of group differences in MNA:
ah.bar_graph(alldf, 'Group', 'Mean Amplitude', 'Condition', output_directory)

# %%
# violin plot of group differences in MNA:
ah.violin(alldf, 'Group', 'Mean Amplitude', 'Condition')

# %%
# box plot of group differences in MNA:
ah.boxplot(alldf, 'Group', 'Mean Amplitude', 'Condition')

# %% [markdown]
# ### Difference data visualization:

# %%
# histogram of diff MNA values:
ah.histogram(diffdf, 'Mean Amplitude', output_directory)
# Out:
# alt.Chart(...)

# %%
# regression plot of time in sound and MNA diff (color code by group):
ah.regression_plot(diffdf, 'Time in Sound (months)', 'Mean Amplitude Difference', 'Group', output_directory)

# %%
# scatter plot of age of implant and MNA diff (include tooltip interactivity):

varlist = ['ID', 'Bilingual', 'Age (months)', 'Time in Sound (months)'] # for tooltip interactivity
ah.scatter_plot(diffdf, 'Age of Activation (months)', 'Mean Amplitude Difference', 'Bilingual', varlist, output_directory)
# Out:
# alt.Chart(...)

# %%
# scatter plot matrix of different variables (TiS, age of implant, MNA):
x_list = ['Time in Sound (months)', 'Age of Activation (months)', 'Mean Amplitude Difference']
ah.scatter_matrix(diffdf, x_list, 'Bilingual', output_directory)
# Out:
# alt.RepeatChart(...)
