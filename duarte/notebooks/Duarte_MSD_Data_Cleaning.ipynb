# %% [markdown]
# # Crossmodal Capture Study Data Cleaning

# %%
#importing necessary packages
import pandas as pd
import numpy as np
from glob import glob
import os

# %%
# changes current working directory
os.chdir(os.path.dirname(os.path.abspath('/Users/sheaduarte/Desktop/School/PSC290python/final/AnalysisHelper.py')))

# %%
import AnalysisHelper as ah
from AnalysisHelper import EyeTrackingHelper

# %% [markdown]
# ### Import Behavioral Data

# %%
# import raw multisensory experiment (MSD) data
MSDraw = ah.import_all_csvs('/Users/sheaduarte/Desktop/School/PSC290python/final/duarte/data/behavioral')

# %%
# create variable in MSD to check accuracy
MSDraw['corrCheck'] = MSDraw['corrAns'] == MSDraw['key_resp_2.keys']

# %% [markdown]
# Clean it up:
# - filter columns
# - rename columns
# - add some grouping columns that I forgot to specify when building the experiment

# %%
# remove practice trials, filter columns
MSD_minusPrac = MSDraw[MSDraw.expLab != 'prac']
MSD_minusPrac = ah.filter_columns('/Users/sheaduarte/Desktop/School/PSC290python/final/duarte/Shea_keep_columns.txt', MSD_minusPrac)
MSD_minusPrac = ah.rename_columns('/Users/sheaduarte/Desktop/School/PSC290python/final/duarte/Shea_column_rename.txt', MSD_minusPrac)

# %%
# add sound type column
def Add_SoundTypeCol(df, condition = 'condition'):
    df['sound_type'] = (df.condition == 'Hcong') | (df.condition == 'HinCong')|(df.condition == 'Lcong') | (df.condition == 'LinCong')
    df['sound_type'] = df['sound_type'].astype(int)
    df['sound_type'] = df['sound_type'].replace({1: 'Animal', 0: 'White Noise'})
    return df

MSD_minusPrac = Add_SoundTypeCol(MSD_minusPrac)

def Add_SoundLocCol(df, condition = 'condition'):
    df['sound_loc'] = df['condition']
    df['sound_loc'] = df.sound_loc.replace({'Hcong': 'Duck1', 'HcongWN': 'Duck1', 'HinCong': 'Frog1', 'HinCongWN': 'Frog1', 'Lcong': 'Frog2',
                                            'LcongWN': 'Frog2', 'LinCong': 'Duck2', 'LinCongWN': 'Duck2' })
    return df
MSD_minusPrac = Add_SoundLocCol(MSD_minusPrac)
MSD_minusPrac
# Out:
#     targetAnim      left_anim     right_anim       right_landolt  \
# 0          NaN            NaN            NaN                 NaN
# 6          NaN            NaN            NaN                 NaN
# 7         frog  duckFront.png  frogFront.png     landoltCTop.png
# 8         frog  duckFront.png  frogFront.png  landoltCBottom.png
# 9         frog  duckFront.png  frogFront.png     landoltCTop.png
# ..         ...            ...            ...                 ...
# 562       duck  frogFront.png  duckFront.png     landoltCTop.png
# 563       duck  frogFront.png  duckFront.png     landoltCTop.png
# 564       frog  duckFront.png  frogFront.png     landoltCTop.png
# 565       duck  frogFront.png  duckFront.png  landoltCBottom.png
# 566       duck  duckFront.png  frogFront.png       landoltCL.png
#
#         left_landolt  condition corrAns     audioPos  repetition  \
# 0                NaN        NaN     NaN          NaN         NaN
# 6                NaN        NaN     NaN          NaN         NaN
# 7      landoltCL.png      Hcong       h  ribbitR.wav         0.0
# 8      landoltCR.png  HinCongWN       b      wnL.wav         0.0
# 9      landoltCL.png    HinCong       h   quackL.wav         0.0
# ..               ...        ...     ...          ...         ...
# 562    landoltCR.png    HinCong       h  ribbitL.wav         6.0
# 563    landoltCL.png    HcongWN       h      wnR.wav         6.0
# 564    landoltCL.png    LinCong       h   quackL.wav         6.0
# 565    landoltCR.png    HinCong       b  ribbitL.wav         6.0
# 566  landoltCTop.png    HinCong       h  ribbitR.wav         6.0
#
#      trial_in_rep  ...  trial_idx  key_pressed reaction_time  \
# 0             NaN  ...        NaN          NaN           NaN
# 6             NaN  ...        NaN          NaN           NaN
# 7             0.0  ...       28.0            h      0.684346
# 8             1.0  ...       23.0            b      1.418252
# 9             2.0  ...       46.0            h      1.218290
# ..            ...  ...        ...          ...           ...
# 562          75.0  ...        6.0            h      0.784165
# 563          76.0  ...        5.0            h      1.051047
# 564          77.0  ...       30.0            h      0.784375
# 565          78.0  ...       62.0            b      0.650831
# 566          79.0  ...        2.0            h      0.633784
#
#                  date  frameRate   expName participant  corrCheck  \
# 0    2020_Mar_04_1508  59.971444  duckFrog          12      False
# 6    2020_Mar_04_1508  59.971444  duckFrog          12      False
# 7    2020_Mar_04_1508  59.971444  duckFrog          12       True
# 8    2020_Mar_04_1508  59.971444  duckFrog          12       True
# 9    2020_Mar_04_1508  59.971444  duckFrog          12       True
# ..                ...        ...       ...         ...        ...
# 562  2020_Feb_26_1011  59.958637  duckFrog           3       True
# 563  2020_Feb_26_1011  59.958637  duckFrog           3       True
# 564  2020_Feb_26_1011  59.958637  duckFrog           3       True
# 565  2020_Feb_26_1011  59.958637  duckFrog           3       True
# 566  2020_Feb_26_1011  59.958637  duckFrog           3       True
#
#       sound_type sound_loc
# 0    White Noise       NaN
# 6    White Noise       NaN
# 7         Animal     Duck1
# 8    White Noise     Frog1
# 9         Animal     Frog1
# ..           ...       ...
# 562       Animal     Frog1
# 563  White Noise     Duck1
# 564       Animal     Duck2
# 565       Animal     Frog1
# 566       Animal     Frog1
#
# [5620 rows x 21 columns]

# %%
# quick accuracy check
MSD_minusPrac.groupby('participant').apply(ah.SjAcc)
# Out:
# 0.9626334519572953
# 0.9893238434163701
# 0.9483985765124555
# 0.9537366548042705
# 0.9466192170818505
# 0.9857651245551602
# 0.9875444839857651
# 0.9679715302491103
# 0.9928825622775801
# 0.9750889679715302
# Empty DataFrame
# Columns: []
# Index: []

# %%
# clean data: remove outliers, reset trial #s, reset indices
MSDall = MSD_minusPrac.groupby(['participant','condition']).apply(ah.remove_outliers, var='reaction_time')
MSDall['trial'] += 1
MSD_behavioral = MSDall[MSDall['corrCheck'] == True]
MSDall = MSDall.reset_index(drop=True)
MSD_behavioral = MSD_behavioral.reset_index(drop=True)

# save MSDall to csv
MSDall.to_csv('/Users/sheaduarte/Desktop/School/PSC290python/final/duarte/data/interim/MSDall.csv')

# %%
MSD_behavioral
# Out:
#      targetAnim      left_anim     right_anim       right_landolt  \
# 0          frog  duckFront.png  frogFront.png     landoltCTop.png
# 1          frog  duckFront.png  frogFront.png  landoltCBottom.png
# 2          frog  frogFront.png  duckFront.png       landoltCR.png
# 3          frog  frogFront.png  duckFront.png       landoltCL.png
# 4          frog  duckFront.png  frogFront.png  landoltCBottom.png
# ...         ...            ...            ...                 ...
# 5253       frog  duckFront.png  frogFront.png  landoltCBottom.png
# 5254       frog  frogFront.png  duckFront.png       landoltCL.png
# 5255       frog  duckFront.png  frogFront.png  landoltCBottom.png
# 5256       frog  duckFront.png  frogFront.png     landoltCTop.png
# 5257       frog  frogFront.png  duckFront.png       landoltCR.png
#
#             left_landolt  condition corrAns     audioPos  repetition  \
# 0          landoltCL.png      Hcong       h  ribbitR.wav         0.0
# 1          landoltCL.png      Hcong       b  ribbitR.wav         0.0
# 2        landoltCTop.png      Hcong       h  ribbitL.wav         0.0
# 3     landoltCBottom.png      Hcong       b  ribbitL.wav         0.0
# 4          landoltCL.png      Hcong       b  ribbitR.wav         0.0
# ...                  ...        ...     ...          ...         ...
# 5253       landoltCR.png  LinCongWN       b      wnL.wav         5.0
# 5254     landoltCTop.png  LinCongWN       h      wnR.wav         6.0
# 5255       landoltCR.png  LinCongWN       b      wnL.wav         6.0
# 5256       landoltCR.png  LinCongWN       h      wnL.wav         6.0
# 5257  landoltCBottom.png  LinCongWN       b      wnR.wav         6.0
#
#       trial_in_rep  ...  trial_idx  key_pressed reaction_time  \
# 0             13.0  ...       60.0            h      0.800653
# 1             18.0  ...       36.0            b      0.800833
# 2             23.0  ...       40.0            h      0.483786
# 3             26.0  ...       64.0            b      0.850971
# 4             27.0  ...       68.0            b      0.667272
# ...            ...  ...        ...          ...           ...
# 5253          69.0  ...       23.0            b      0.967617
# 5254           4.0  ...       27.0            h      1.200920
# 5255           5.0  ...       23.0            b      1.067533
# 5256          40.0  ...       31.0            h      1.267934
# 5257          62.0  ...       19.0            b      1.184089
#
#                   date  frameRate   expName participant  corrCheck  \
# 0     2020_Feb_26_0910  59.952707  duckFrog           2       True
# 1     2020_Feb_26_0910  59.952707  duckFrog           2       True
# 2     2020_Feb_26_0910  59.952707  duckFrog           2       True
# 3     2020_Feb_26_0910  59.952707  duckFrog           2       True
# 4     2020_Feb_26_0910  59.952707  duckFrog           2       True
# ...                ...        ...       ...         ...        ...
# 5253  2020_Mar_11_1110  59.950336  duckFrog          16       True
# 5254  2020_Mar_11_1110  59.950336  duckFrog          16       True
# 5255  2020_Mar_11_1110  59.950336  duckFrog          16       True
# 5256  2020_Mar_11_1110  59.950336  duckFrog          16       True
# 5257  2020_Mar_11_1110  59.950336  duckFrog          16       True
#
#        sound_type sound_loc
# 0          Animal     Duck1
# 1          Animal     Duck1
# 2          Animal     Duck1
# 3          Animal     Duck1
# 4          Animal     Duck1
# ...           ...       ...
# 5253  White Noise     Duck2
# 5254  White Noise     Duck2
# 5255  White Noise     Duck2
# 5256  White Noise     Duck2
# 5257  White Noise     Duck2
#
# [5258 rows x 21 columns]

# %% [markdown]
# ### Import Eyetracking Data

# %%
# import eyetracking csv files
MSDeyeRaw = ah.import_all_csvs('/Users/sheaduarte/Desktop/School/PSC290python/final/duarte/data/eyetracking')

# %%
# filter columns
MSDeyeRaw = ah.filter_columns('/Users/sheaduarte/Desktop/School/PSC290python/final/duarte/SheaEyetracking_keep_columns.txt', MSDeyeRaw)
MSDeyeRaw = ah.rename_columns('/Users/sheaduarte/Desktop/School/PSC290python/final/duarte/SheaEyetracking_rename_columns.txt', MSDeyeRaw)

# %%
# create EyeTrackingHelper object
MSDeye = ah.EyeTrackingHelper(MSDeyeRaw)
MSDeye.RawEyeDF
# Out:
#       participant  trial  total_fixations current_fix_dur  current_fix_idx  \
# 0               4      1                7              32                1
# 1               4      1                7            1256                2
# 2               4      1                7             352                3
# 3               4      1                7             428                4
# 4               4      1                7             288                5
# ...           ...    ...              ...             ...              ...
# 2038           10    559                3             176                3
# 2039           10    560                4             444                1
# 2040           10    560                4             286                2
# 2041           10    560                4             136                3
# 2042           10    560                4             212                4
#
#      current_IA_id current_IA_label running_dwell_time  \
# 0                .                .                  .
# 1                .                .                  .
# 2                .                .                  .
# 3                .                .                  .
# 4                .                .                  .
# ...            ...              ...                ...
# 2038             2         targetIA                394
# 2039             1       fixationIA                444
# 2040             2         targetIA                634
# 2041             2         targetIA                634
# 2042             2         targetIA                634
#
#      current_fix_IA_fixcount current_fix_dur  current_fix_start_time  \
# 0                          .               .                       0
# 1                          .               .                      48
# 2                          .               .                    1380
# 3                          .               .                    1752
# 4                          .               .                    2828
# ...                      ...             ...                     ...
# 2038                       2             394                    1110
# 2039                       1             444                       4
# 2040                       3             634                     526
# 2041                       3             634                     828
# 2042                       3             634                     978
#
#      nearest_IA nearest_IA_distance nearest_IA_label
# 0             .                   .                .
# 1             .                   .                .
# 2             .                   .                .
# 3             .                   .                .
# 4             .                   .                .
# ...         ...                 ...              ...
# 2038          2                1.11         targetIA
# 2039          1                0.58       fixationIA
# 2040          2                0.66         targetIA
# 2041          2                1.11         targetIA
# 2042          2                0.76         targetIA
#
# [23334 rows x 14 columns]

# %%
# create master eye df
# note: this study uses a fixation interest area, so we will only store this as a tmp dataframe so that we can also use our first fixation method
tmp = MSDeye.CleanEyeTracking_MasterDF(currentFixationIdx = 'current_fix_idx', nearestIAVar = 'nearest_IA_label', currentFixDurationVar='current_fix_dur', fixationTotalVar='total_fixations')

# %%
MSD_eye = MSDeye.Add_First_Fixation(df = tmp, fixation1Var = 'fixation1',fixation2Var= 'fixation2', fixation3Var='fixation3', fixDuration1='fix_dur_1', fixDuration2='fix_dur_2', fixDuration3='fix_dur_3')

# %% [markdown]
# ### Merge behavioral and eye tracking data

# %%
# merge behavioral and eye tracking, send to csv
MSD = pd.merge(MSD_eye, MSD_behavioral, on =['trial', 'participant'], how = 'outer')
MSD.to_csv('/Users/sheaduarte/Desktop/School/PSC290python/final/duarte/data/processed/MSD.csv')

MSD.shape
# Out:
# (5600, 33)

# %%
# check over the data
pd.set_option('display.max_columns', None)
MSD.head(20)
# Out:
#     trial  participant  total_fixations latency   fixation0   fixation1  \
# 0       1            4                7      32           .           .
# 1       2            4               10    1632  fixationIA    targetIA
# 2       3            4                4    1148  fixationIA    targetIA
# 3       4            4                4    1332  fixationIA      distIA
# 4       5            4                5    1276  fixationIA    targetIA
# 5       6            4                5     996  fixationIA      distIA
# 6       7            4                6    1196  fixationIA      distIA
# 7       8            4                4     992  fixationIA      distIA
# 8       9            4                5     428  fixationIA  fixationIA
# 9      10            4                6    1008  fixationIA      distIA
# 10     11            4                5    1288  fixationIA      distIA
# 11     12            4                6     972  fixationIA    targetIA
# 12     13            4                6     788  fixationIA    targetIA
# 13     14            4                4    1056  fixationIA    targetIA
# 14     15            4                5    1252  fixationIA      distIA
# 15     16            4                3     956  fixationIA    targetIA
# 16     17            4               10     252  fixationIA    targetIA
# 17     18            4                3    1072  fixationIA    targetIA
# 18     19            4                5     960  fixationIA      distIA
# 19     20            4                6    1164  fixationIA    targetIA
#
#     fix_dur_1 fixation2  fix_dur_2   fixation3  fix_dur_3 fixation4  \
# 0      1256.0         .      352.0           .      428.0         .
# 1       136.0  targetIA      204.0    targetIA      540.0  targetIA
# 2       180.0  targetIA      280.0    targetIA      428.0       NaN
# 3       576.0  targetIA      132.0    targetIA     1228.0       NaN
# 4       652.0  targetIA      140.0    targetIA      344.0    distIA
# 5       596.0  targetIA      100.0    targetIA      168.0  targetIA
# 6       220.0    distIA      268.0    targetIA      164.0  targetIA
# 7      1024.0  targetIA      168.0    targetIA      476.0       NaN
# 8       584.0    distIA      680.0    targetIA      176.0  targetIA
# 9       200.0    distIA      300.0    targetIA      172.0  targetIA
# 10      248.0    distIA      104.0    targetIA      164.0  targetIA
# 11      176.0  targetIA      456.0      distIA      116.0    distIA
# 12      200.0  targetIA      960.0      distIA      112.0    distIA
# 13      476.0    distIA      176.0      distIA      240.0       NaN
# 14      224.0    distIA       92.0    targetIA      176.0  targetIA
# 15      152.0  targetIA      580.0         NaN        NaN       NaN
# 16      152.0  targetIA      256.0  fixationIA      348.0    distIA
# 17      244.0  targetIA      492.0         NaN        NaN       NaN
# 18      392.0  targetIA      160.0    targetIA      184.0  targetIA
# 19      344.0  targetIA      228.0      distIA      252.0  targetIA
#
#    first_fixation  first_fix_dwell targetAnim      left_anim     right_anim  \
# 0               .           1256.0        NaN            NaN            NaN
# 1        targetIA            136.0        NaN            NaN            NaN
# 2        targetIA            180.0       frog  frogFront.png  duckFront.png
# 3          distIA            576.0        NaN            NaN            NaN
# 4        targetIA            652.0       frog  duckFront.png  frogFront.png
# 5          distIA            596.0       frog  duckFront.png  frogFront.png
# 6          distIA            220.0       duck  duckFront.png  frogFront.png
# 7          distIA           1024.0       frog  duckFront.png  frogFront.png
# 8          distIA            680.0       frog  frogFront.png  duckFront.png
# 9          distIA            200.0       frog  duckFront.png  frogFront.png
# 10         distIA            248.0       frog  duckFront.png  frogFront.png
# 11       targetIA            176.0       duck  duckFront.png  frogFront.png
# 12       targetIA            200.0        NaN            NaN            NaN
# 13       targetIA            476.0       frog  frogFront.png  duckFront.png
# 14         distIA            224.0       frog  duckFront.png  frogFront.png
# 15       targetIA            152.0       frog  frogFront.png  duckFront.png
# 16       targetIA            152.0        NaN            NaN            NaN
# 17       targetIA            244.0       frog  frogFront.png  duckFront.png
# 18         distIA            392.0       duck  duckFront.png  frogFront.png
# 19       targetIA            344.0       frog  frogFront.png  duckFront.png
#
#          right_landolt        left_landolt  condition corrAns     audioPos  \
# 0                  NaN                 NaN        NaN     NaN          NaN
# 1                  NaN                 NaN        NaN     NaN          NaN
# 2        landoltCL.png     landoltCTop.png    HcongWN       h      wnL.wav
# 3                  NaN                 NaN        NaN     NaN          NaN
# 4   landoltCBottom.png       landoltCR.png    HcongWN       b      wnR.wav
# 5      landoltCTop.png       landoltCR.png  HinCongWN       h      wnL.wav
# 6        landoltCR.png  landoltCBottom.png    LinCong       b  ribbitR.wav
# 7   landoltCBottom.png       landoltCR.png  HinCongWN       b      wnL.wav
# 8        landoltCL.png  landoltCBottom.png    HinCong       b   quackR.wav
# 9      landoltCTop.png       landoltCL.png    HinCong       h   quackL.wav
# 10  landoltCBottom.png       landoltCR.png  HinCongWN       b      wnL.wav
# 11       landoltCR.png     landoltCTop.png    LcongWN       h      wnL.wav
# 12                 NaN                 NaN        NaN     NaN          NaN
# 13       landoltCR.png  landoltCBottom.png  HinCongWN       b      wnR.wav
# 14  landoltCBottom.png       landoltCL.png    HinCong       b   quackL.wav
# 15       landoltCR.png  landoltCBottom.png    HcongWN       b      wnL.wav
# 16                 NaN                 NaN        NaN     NaN          NaN
# 17       landoltCR.png     landoltCTop.png      Hcong       h  ribbitL.wav
# 18       landoltCL.png  landoltCBottom.png  LinCongWN       b      wnR.wav
# 19       landoltCL.png     landoltCTop.png  HinCongWN       h      wnR.wav
#
#     repetition  trial_in_rep  trial_idx key_pressed  reaction_time  \
# 0          NaN           NaN        NaN         NaN            NaN
# 1          NaN           NaN        NaN         NaN            NaN
# 2          0.0           2.0       41.0           h       1.568276
# 3          NaN           NaN        NaN         NaN            NaN
# 4          0.0           4.0       37.0           b       2.202140
# 5          0.0           5.0       63.0           h       2.135226
# 6          0.0           6.0       10.0           b       1.868055
# 7          0.0           7.0       55.0           b       2.218382
# 8          0.0           8.0       66.0           b       1.918261
# 9          0.0           9.0       46.0           h       1.651253
# 10         0.0          10.0       23.0           b       1.734918
# 11         0.0          11.0        1.0           h       2.435185
# 12         NaN           NaN        NaN         NaN            NaN
# 13         0.0          13.0       67.0           b       1.501371
# 14         0.0          14.0       22.0           b       1.718000
# 15         0.0          15.0       49.0           b       1.151076
# 16         NaN           NaN        NaN         NaN            NaN
# 17         0.0          17.0       56.0           h       1.184456
# 18         0.0          18.0       11.0           b       1.768329
# 19         0.0          19.0       27.0           h       1.935085
#
#                 date  frameRate   expName corrCheck   sound_type sound_loc
# 0                NaN        NaN       NaN       NaN          NaN       NaN
# 1                NaN        NaN       NaN       NaN          NaN       NaN
# 2   2020_Feb_26_1123  59.966808  duckFrog      True  White Noise     Duck1
# 3                NaN        NaN       NaN       NaN          NaN       NaN
# 4   2020_Feb_26_1123  59.966808  duckFrog      True  White Noise     Duck1
# 5   2020_Feb_26_1123  59.966808  duckFrog      True  White Noise     Frog1
# 6   2020_Feb_26_1123  59.966808  duckFrog      True       Animal     Duck2
# 7   2020_Feb_26_1123  59.966808  duckFrog      True  White Noise     Frog1
# 8   2020_Feb_26_1123  59.966808  duckFrog      True       Animal     Frog1
# 9   2020_Feb_26_1123  59.966808  duckFrog      True       Animal     Frog1
# 10  2020_Feb_26_1123  59.966808  duckFrog      True  White Noise     Frog1
# 11  2020_Feb_26_1123  59.966808  duckFrog      True  White Noise     Frog2
# 12               NaN        NaN       NaN       NaN          NaN       NaN
# 13  2020_Feb_26_1123  59.966808  duckFrog      True  White Noise     Frog1
# 14  2020_Feb_26_1123  59.966808  duckFrog      True       Animal     Frog1
# 15  2020_Feb_26_1123  59.966808  duckFrog      True  White Noise     Duck1
# 16               NaN        NaN       NaN       NaN          NaN       NaN
# 17  2020_Feb_26_1123  59.966808  duckFrog      True       Animal     Duck1
# 18  2020_Feb_26_1123  59.966808  duckFrog      True  White Noise     Duck2
# 19  2020_Feb_26_1123  59.966808  duckFrog      True  White Noise     Frog1
